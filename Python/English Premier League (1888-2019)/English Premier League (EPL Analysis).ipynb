# %% [markdown]
# <h1> <center>English Premier League (EPL) Analaysis (FROM 1888-2019)
#
# <img src="http://pluspng.com/img-png/english-football-league-logo-png-premier-league-logo-340.png" alt="English Football League Logo PNG" width="200" height="200"> </center>

# %% [markdown]
# #### Dr. Sulove Koirala
# <i> (A veterinarian who is interested in learning some programming) </i><br>
# #### Email: sulovekoirala@gmail.com

# %% [markdown]
# ## Introduction
# We are going to get a dataset that contains results of 1,078,214 football games in 207 top-tier domestic leagues and 20 international tournaments (UEFA EuroLeague/ChampionsLeague,etc.) from 1888-2019. Here, we will just look at the English Premier League Games only.
#
# Dataset Source: https://github.com/schochastics/football-data<br>
# I would like to thank the author for making this dataset available publicly.

# %% [markdown]
# ## Loading the Packages
# We wiill also download the dataset using the direct url.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/schochastics/football-data/master/data/results/england.csv'
data = pd.read_csv(url)

# %%
data.head()
# Out:
#                       home                  away        date  gh  ga  \
# 0         Bolton Wanderers          Derby County  1888-09-08   3   6
# 1               Everton FC         Accrington FC  1888-09-08   2   1
# 2        Preston North End            Burnley FC  1888-09-08   5   2
# 3               Stoke City  West Bromwich Albion  1888-09-08   0   2
# 4  Wolverhampton Wanderers           Aston Villa  1888-09-08   1   1
#
#   full_time competition                         home_ident  \
# 0         F     england         Bolton Wanderers (England)
# 1         F     england               Everton FC (England)
# 2         F     england        Preston North End (England)
# 3         F     england               Stoke City (England)
# 4         F     england  Wolverhampton Wanderers (England)
#
#                        away_ident home_country away_country home_code  \
# 0          Derby County (England)      england      england       ENG
# ...

# %% [markdown]
# <p>The full form of acronyms in the table are</p> <BR>
# <table>
# <thead>
# <tr>
# <th>variable</th>
# <th>description</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>home</td>
# <td>home team name (not necessarily unique)</td>
# </tr>
# <tr>
# <td>away</td>
# <td>away team name (not necessarily unique)</td>
# </tr>
# <tr>
# <td>date</td>
# <td>date of match</td>
# </tr>
# <tr>
# <td>gh</td>
# <td>goals for home team (including extra time and penalties)</td>
# </tr>
# <tr>
# <td>ga</td>
# <td>goals for away team (including extra time and penalties)</td>
# </tr>
# <tr>
# <td>full_time</td>
# <td>"F"=game ended in 90', "E"=extra time, "P"=penalty shoot-out</td>
# </tr>
# <tr>
# <td>competition</td>
# <td>country name of league or name of international competition</td>
# </tr>
# <tr>
# <td>home_ident</td>
# <td>unique identifier of home team</td>
# </tr>
# <tr>
# <td>away_ident</td>
# <td>unique identifier of away team</td>
# </tr>
# <tr>
# <td>home_country</td>
# <td>country of home team</td>
# </tr>
# <tr>
# <td>away_country</td>
# <td>country of away team</td>
# </tr>
# <tr>
# <td>home_code</td>
# <td>country code of home team</td>
# </tr>
# <tr>
# <td>away_code</td>
# <td>country code of away team</td>
# </tr>
# <tr>
# <td>home_continent</td>
# <td>continent of home team</td>
# </tr>
# <tr>
# <td>away_continent</td>
# <td>continent of away team</td>
# </tr>
# <tr>
# <td>continent</td>
# <td>continent of competition</td>
# </tr>
# <tr>
# <td>level</td>
# <td>"national"= domestic league, "international"= international cup</td>
# </tr>
# </tbody>
#     </table>

# %% [markdown]
# ## Analyzing the data

# %%
data.describe()
# Out:
#                  gh            ga
# count  48670.000000  48670.000000
# mean       1.810376      1.167146
# std        1.468616      1.142188
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        2.000000      1.000000
# 75%        3.000000      2.000000
# max       12.000000      9.000000

# %% [markdown]
# It shows the mean, standard deviation and quartiles. Also, it shows the maximum number as well. Let's highlight what we got. <br>
# <b> Maximum Goal Scored by Home Side: 12 <br>
#     Maximum Goal Scored by Away Side: 9 <br>

# %% [markdown]
# Now I have developed a curiosity and want to see which side scored and which side conceaded that record number of goals.
# ### <font color = "blue"> <b> Which side has scored the highest goals in a single home and an away match? </b></font>

# %%
data [data['gh'] == 12]
# Out:
#                       home            away        date  gh  ga full_time  \
# 729            Aston Villa   Accrington FC  1892-03-12  12   2         F
# 756   West Bromwich Albion          Darwen  1892-04-04  12   0         F
# 9011     Nottingham Forest  Leicester City  1909-04-21  12   0         F
#
#      competition                      home_ident                away_ident  \
# 729      england           Aston Villa (England)   Accrington FC (England)
# 756      england  West Bromwich Albion (England)          Darwen (England)
# 9011     england     Nottingham Forest (England)  Leicester City (England)
#
#      home_country away_country home_code away_code home_continent  \
# 729       england      england       ENG       ENG         Europe
# 756       england      england       ENG       ENG         Europe
# 9011      england      england       ENG       ENG         Europe
#
#      away_continent continent     level
# 729          Europe    Europe  national
# ...

# %%
data [data['ga'] == 9]
# Out:
#                     home                     away        date  gh  ga  \
# 8583    Newcastle United           Sunderland Afc  1908-12-05   1   9
# 112292      Cardiff City  Wolverhampton Wanderers  1955-09-03   1   9
#
#        full_time competition                  home_ident  \
# 8583           F     england  Newcastle United (England)
# 112292         F     england        Cardiff City (Wales)
#
#                                away_ident home_country away_country home_code  \
# 8583             Sunderland Afc (England)      england      england       ENG
# 112292  Wolverhampton Wanderers (England)        wales      england       WAL
#
#        away_code home_continent away_continent continent     level
# 8583         ENG         Europe         Europe    Europe  national
# 112292       ENG         Europe         Europe    Europe  national

# %% [markdown]
# So these are the instances when the away goals were nine and home goals were 12.

# %% [markdown]
# ### <font color = "blue"> <b>How many unique premier league teams were there and who played the most matches?
# We will make home and away column into a single one using stack command and use the value counts

# %%
teams = data[['home','away']].stack().value_counts().rename_axis('Team').reset_index(name='counts')
teams
# Out:
#                  Team  counts
# 0          Everton FC    4518
# 1        Liverpool FC    4134
# 2          Arsenal FC    4134
# 3         Aston Villa    4070
# 4   Manchester United    3778
# ..                ...     ...
# 61   Northampton Town      42
# 62       Swindon Town      42
# 63      Leyton Orient      42
# 64        Barnsley FC      38
# 65  Glossop North End      34
#
# [66 rows x 2 columns]

# %% [markdown]
# Great. Now we know that <b> <font color = 'red'> Everton </font></b>has played the most matches between 1888 and 2019. There were altogether <b> <font color = 'red'>66</font></b> different teams. Glossop North End played the least number of matches.

# %% [markdown]
# ### <font color = "blue"> <b> Which Team has won the most number of home matches? </b></font>

# %%
home = data[(data['gh'] > data['ga'])]
home = home['home'].value_counts().rename_axis('Team').reset_index(name='points')
home["points"] = 3 * home["points"]
home
# Out:
#                  Team  points
# 0        Liverpool FC    3732
# 1          Everton FC    3699
# 2          Arsenal FC    3597
# 3   Manchester United    3393
# 4         Aston Villa    3318
# ..                ...     ...
# 61    Carlisle United      24
# 62        Barnsley FC      21
# 63  Glossop North End      12
# 64       Swindon Town      12
# 65      Leyton Orient      12
#
# [66 rows x 2 columns]

# %% [markdown]
# <b> <font color = 'red'>Liverpool </font></B>is the home bullys and Everton not far behind. Lyton Orient, Glossop and Swindon just won 4 matches (12pts) overall.

# %% [markdown]
# ### <font color = "blue"> <b> Which Team has won the most number of away matches? </b></font>

# %%
away = data[(data['ga'] > data['gh'])]
away = away['away'].value_counts().rename_axis('Team').reset_index(name='points')
away["points"] = 3 * away["points"]
away
# Out:
#                  Team  points
# 0        Liverpool FC    2076
# 1          Arsenal FC    2061
# 2   Manchester United    2037
# 3          Everton FC    1812
# 4         Aston Villa    1611
# ..                ...     ...
# 60        Barnsley FC       9
# 61   Northampton Town       6
# 62      Leyton Orient       6
# 63             Darwen       3
# 64       Swindon Town       3
#
# [65 rows x 2 columns]

# %% [markdown]
# Again, <b> <font color = 'red'>Liverpool</font></b> has won the most number of away matches. Arsenal also trailing by a small margin.

# %% [markdown]
# ### <font color = "blue"> <b> Which Team has never won an away match? </b></font>

# %% [markdown]
# We developed this question because we see that there are only 65 Teams displayed in the previous question. There must a team which has not won a single away competition. Let us find which team always had a disappointing outing.  I am going to do this in a hard way as I am a noob. We will combine the teams and away dataset and combine the list of both Teams. The team that didn't win an away match isn't included in the away dataset. Therefore, it's value count will be less.

# %%
dagger = pd.concat([teams, away], axis=1)
dagger[['Team','Team']].stack().value_counts().tail(1) # We are doing tail(1) because there is only one team without away win
# Out:
# Glossop North End    2
# dtype: int64

# %% [markdown]
# <b> <font color = 'red'>"Glossop North End"</b></font>. This is the team that hasn't won any away match since 1888.

# %% [markdown]
# ### <font color = "blue"> <b> Which Team is involved in most number of drawn matches? </b></font>

# %%
drawdata = data[(data['ga'] == data['gh'])]
drawdata
draw = drawdata[['home','away']].stack().value_counts().rename_axis('Team').reset_index(name='points')
draw # We don't need to multiply the matches by a number to get points because the drawn match = 1 point
# Out:
#                  Team  points
# 0          Everton FC    1135
# 1          Arsenal FC    1057
# 2        Liverpool FC    1031
# 3         Aston Villa     968
# 4   Manchester United     928
# ..                ...     ...
# 61  Glossop North End      10
# 62      Leyton Orient       9
# 63             Darwen       8
# 64    Carlisle United       5
# 65        Barnsley FC       5
#
# [66 rows x 2 columns]

# %% [markdown]
# <b> <font color = 'red'>Everton </font></b> has been involved in more drawn matches than any other teams.

# %% [markdown]
# ### <font color = "blue"> <b>Which Team has the most aggregate points since 1888 ? </b></font>

# %% [markdown]
# The reason we calculated points, instead of displaying the number of matches won in home-away, draw before is for answering this question. We will sort the three tables into alphabetical order and add the points. It will display the aggregate points. Sounds complicated. Expert data scientists probably has an easier alternative but noobs will follow the long path. Also I am going to remove 'Glossop North End' from home and draw, the reason is because it will be easier to proceed with addition of points.

# %%
home1 = home[home.Team != 'Glossop North End'].sort_values(by='Team', ascending=True).reset_index()
draw1 = draw[draw.Team != 'Glossop North End'].sort_values(by='Team', ascending=True).reset_index()
away1 = away.sort_values('Team').reset_index() # We don't have to remove 'Glossop North End' because it's not present here
#Therefore, all the above dataset is of similar size and nature and we can proceed with addition. Hope it works !

# %%
total = draw1['points'] + home1['points'] + away1['points']
aggregate = total.rename_axis('Team').reset_index(name='Points')
aggregate['Team'] = home1['Team']
aggregate.sort_values(by='Points', ascending = False).head(10).reset_index (drop = True)
# Out:
#                 Team  Points
# 0       Liverpool FC    6839
# 1         Arsenal FC    6715
# 2         Everton FC    6646
# 3  Manchester United    6358
# 4        Aston Villa    5897
# 5    Manchester City    5229
# 6  Tottenham Hotspur    5050
# 7         Chelsea FC    5034
# 8   Newcastle United    4851
# 9     Sunderland Afc    4560

# %% [markdown]
# It's <font color = "red"> <b>Liverpool</b> </font>. Liverpool is not only leading the 2020 season, they also lead when ranked by overall points. It would be better if we make some visualization out of it.

# %%
top = aggregate.sort_values(by='Points', ascending = False).head(10)
sns.set(style="whitegrid")
plt.figure(figsize=(15,8))
sns.barplot(data = top, x = 'Points', y = 'Team', palette='Set2')
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.yticks( 
    fontweight='light',
    fontsize='16'  
)
plt.show()

# %% [markdown]
# ### Bibiliography

# %% [markdown]
# Schoch, David. (2020). Schochastics/football-data [R]. https://github.com/schochastics/football-data (Original work published 2020)

# %% [markdown]
# Premier League Image Source : <a title="English Football League Logo PNG" href="http://pluspng.com/english-football-league-logo-png-6514.html">English Football League Logo PNG</a>
